# %% [markdown]
# # Consumer Credit Analysis
# ## Tiffany Objectives/To Do:
#
# **Due 2/11**
# - Identify outliers in credit score.csv by excel column (T - AN) compared to AO <br>
# - Find top 3 positive and bottom 3 negative strongest correlations <br>
# - Compare and identify strongest 3 pos/neg correlations, isolate <br><br>
#
# **Due 2/12**
# - Compile report outline/graphs <br><br>
#
# **Due 2/13**
# - PowerPoint <br><br>
#
# **Due 2/13**
# - Presentation <br><br>
#
#
# ## Project Description
# According to Experian, the average FICO score in the US is 715. While there’s no such thing as the average consumer, there are plenty of quantifiable trends and data that the three credit bureaus use to determine creditworthiness. In this project, we’ll examine which demographic and psychographic factors are associated with higher average credit scores and contrast them with factors associated with lower average credit scores. We’ll apply the core concepts learned in class so far, such as data cleaning and statistical analysis, to get to the bottom of how things like payment history, debt-to-income ratio, and age of accounts influence a person’s credit score. <br>
#
# **Research Questions:**
# 1. What are the top 3 positive behaviors associated with high credit scores?
# 2. hat are the bottom 3 negative behaviors associated with lower credit scores?
# 3. What geographic area has the highest average credit scores?

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as st



# loan_data_file = Path("Resources/loan_data_clean_.csv")
# loan_data = pd.read_csv(loan_data_file)
# loan_data.head()
# #291796 rows × 51 columns


credit_score_file = Path("Resources/credit_score_clean.csv")
credit_score = pd.read_csv(credit_score_file)
credit_score.head()


#1000 rows × 41 columns
# Out:
#    YEARLY_INCOME  CURRENT_SAVINGS_TO_YEARLY_INCOME_RATIO  \
# 0          33269                                  0.0000
# 1          77158                                  1.1818
# 2          80657                                  0.8000
# 3         149971                                  7.8182
# 4         181636                                  1.8667
#
#    CURRENT_DEBT_TO_YEARLY_INCOME_RATIO  CURRENT_DEBT_TO_CURRENT_SAVINGS_RATIO  \
# 0                              16.0000                                 1.2000
# 1                               4.0909                                 3.4615
# 2                               7.8000                                 9.7499
# 3                              16.0000                                 2.0465
# 4                               9.3334                                 5.0000
#
#    YEARLY_CLOTHING_TO_YEARLY_INCOME_RATIO  \
# 0                                  0.0568
# 1                                  0.0754
# ...

# %%
credit_score.dtypes
# Out:
# YEARLY_INCOME                                      int64
# CURRENT_SAVINGS_TO_YEARLY_INCOME_RATIO           float64
# CURRENT_DEBT_TO_YEARLY_INCOME_RATIO              float64
# CURRENT_DEBT_TO_CURRENT_SAVINGS_RATIO            float64
# YEARLY_CLOTHING_TO_YEARLY_INCOME_RATIO           float64
# YEARLY_CLOTHING_TO_CURRENT_SAVINGS_RATIO         float64
# YEARLY_CLOTHING_TO_CURRENT_DEBT_RATIO            float64
# YEARLY_EDUCATION_TO_YEARLY_INCOME_RATIO          float64
# YEARLY_EDUCATION_TO_CURRENT_SAVINGS_RATIO        float64
# YEARLY_EDUCATION_TO_CURRENT_DEBT_RATIO           float64
# YEARLY_ENTERTAINMENT_TO_YEARLY_INCOME_RATIO      float64
# YEARLY_ENTERTAINMENT_TO_CURRENT_SAVINGS_RATIO    float64
# YEARLY_ENTERTAINMENT_TO_CURRENT_DEBT_RATIO       float64
# YEARLY_LOAN_FINES_TO_YEARLY_INCOME_RATIO         float64
# YEARLY_LOAN_FINES_TO_CURRENT_SAVINGS_RATIO       float64
# YEARLY_LOAN_FINES_CURRENT_DEBT_RATIO             float64
# ...

# %%
credit_score.min()
# Out:
# YEARLY_INCOME                                      0.0000
# CURRENT_SAVINGS_TO_YEARLY_INCOME_RATIO             0.0000
# CURRENT_DEBT_TO_YEARLY_INCOME_RATIO                0.0000
# CURRENT_DEBT_TO_CURRENT_SAVINGS_RATIO              0.0000
# YEARLY_CLOTHING_TO_YEARLY_INCOME_RATIO             0.0034
# YEARLY_CLOTHING_TO_CURRENT_SAVINGS_RATIO           0.0000
# YEARLY_CLOTHING_TO_CURRENT_DEBT_RATIO              0.0000
# YEARLY_EDUCATION_TO_YEARLY_INCOME_RATIO            0.0000
# YEARLY_EDUCATION_TO_CURRENT_SAVINGS_RATIO          0.0000
# YEARLY_EDUCATION_TO_CURRENT_DEBT_RATIO             0.0000
# YEARLY_ENTERTAINMENT_TO_YEARLY_INCOME_RATIO        0.0000
# YEARLY_ENTERTAINMENT_TO_CURRENT_SAVINGS_RATIO      0.0000
# YEARLY_ENTERTAINMENT_TO_CURRENT_DEBT_RATIO         0.0000
# YEARLY_LOAN_FINES_TO_YEARLY_INCOME_RATIO           0.0000
# YEARLY_LOAN_FINES_TO_CURRENT_SAVINGS_RATIO         0.0000
# YEARLY_LOAN_FINES_CURRENT_DEBT_RATIO               0.0000
# ...

# %%
#Data on all numeric columns
credit_score.describe()
# Out:
#        YEARLY_INCOME  CURRENT_SAVINGS_TO_YEARLY_INCOME_RATIO  \
# count    1000.000000                             1000.000000
# mean   121610.019000                                4.063477
# std    113716.699591                                3.968097
# min         0.000000                                0.000000
# 25%     30450.250000                                1.000000
# 50%     85090.000000                                2.545450
# 75%    181217.500000                                6.307100
# max    662094.000000                               16.111200
#
#        CURRENT_DEBT_TO_YEARLY_INCOME_RATIO  \
# count                          1000.000000
# mean                              6.068449
# std                               5.847878
# min                               0.000000
# 25%                               1.454500
# 50%                               4.911550
# 75%                               8.587475
# max                              37.000600
#
# ...

# %%
#Correlations for the entire datasheet
credit_score.corr()
# Out:
#                                                YEARLY_INCOME  \
# YEARLY_INCOME                                       1.000000
# CURRENT_SAVINGS_TO_YEARLY_INCOME_RATIO             -0.182221
# CURRENT_DEBT_TO_YEARLY_INCOME_RATIO                 0.076101
# CURRENT_DEBT_TO_CURRENT_SAVINGS_RATIO              -0.142151
# YEARLY_CLOTHING_TO_YEARLY_INCOME_RATIO              0.015526
# YEARLY_CLOTHING_TO_CURRENT_SAVINGS_RATIO           -0.120578
# YEARLY_CLOTHING_TO_CURRENT_DEBT_RATIO              -0.125077
# YEARLY_EDUCATION_TO_YEARLY_INCOME_RATIO            -0.130948
# YEARLY_EDUCATION_TO_CURRENT_SAVINGS_RATIO          -0.158177
# YEARLY_EDUCATION_TO_CURRENT_DEBT_RATIO             -0.017487
# YEARLY_ENTERTAINMENT_TO_YEARLY_INCOME_RATIO        -0.393212
# YEARLY_ENTERTAINMENT_TO_CURRENT_SAVINGS_RATIO      -0.244285
# YEARLY_ENTERTAINMENT_TO_CURRENT_DEBT_RATIO         -0.202292
# YEARLY_LOAN_FINES_TO_YEARLY_INCOME_RATIO           -0.056566
# ...

# %%
#Heat map to represent correlation for entire data sheet all columns with all... 
#Lighter spots represent stronger correlations... 
#Darker spots represent weaker correlations
#The lightest spots (diagnal line) and when it is same column and correlation is 1 (ie YEARLY_INCOME, YEARLY_INCOME; CREDIT_SCORE, CREDIT_SCORE, ETC)

sns.heatmap(credit_score.corr());

# %%
credit_score.columns
# Out:
# Index(['YEARLY_INCOME', 'CURRENT_SAVINGS_TO_YEARLY_INCOME_RATIO',
#        'CURRENT_DEBT_TO_YEARLY_INCOME_RATIO',
#        'CURRENT_DEBT_TO_CURRENT_SAVINGS_RATIO',
#        'YEARLY_CLOTHING_TO_YEARLY_INCOME_RATIO',
#        'YEARLY_CLOTHING_TO_CURRENT_SAVINGS_RATIO',
#        'YEARLY_CLOTHING_TO_CURRENT_DEBT_RATIO',
#        'YEARLY_EDUCATION_TO_YEARLY_INCOME_RATIO',
#        'YEARLY_EDUCATION_TO_CURRENT_SAVINGS_RATIO',
#        'YEARLY_EDUCATION_TO_CURRENT_DEBT_RATIO',
#        'YEARLY_ENTERTAINMENT_TO_YEARLY_INCOME_RATIO',
#        'YEARLY_ENTERTAINMENT_TO_CURRENT_SAVINGS_RATIO',
#        'YEARLY_ENTERTAINMENT_TO_CURRENT_DEBT_RATIO',
#        'YEARLY_LOAN_FINES_TO_YEARLY_INCOME_RATIO',
#        'YEARLY_LOAN_FINES_TO_CURRENT_SAVINGS_RATIO',
#        'YEARLY_LOAN_FINES_CURRENT_DEBT_RATIO',
#        'YEARLY_GAMBLING_TO_YEARLY_INCOME_RATIO',
#        'YEARLY_GAMBLING_TO_CURRENT_SAVINGS_RATIO',
#        'YEARLY_GAMBLING_TO_CURRENT_DEBT_RATIO',
# ...

# %%
#Rename Columns for readability
#Data column names are Rations
credit_score_df = credit_score.rename(columns = {'YEARLY_INCOME': 'Yearly Income', 
                                   'CURRENT_SAVINGS_TO_YEARLY_INCOME_RATIO': 'Current Savings : Yearly Income',
                                   'CURRENT_DEBT_TO_YEARLY_INCOME_RATIO': 'Current Debt : Yearly Income', 
                                   'CURRENT_DEBT_TO_CURRENT_SAVINGS_RATIO': 'Current Debt : Current Savings',
                                   'YEARLY_CLOTHING_TO_YEARLY_INCOME_RATIO': 'Yearly Clothing : Yearly Income',
                                   'YEARLY_CLOTHING_TO_CURRENT_SAVINGS_RATIO': 'Yearly Clothing : Current Savings',
                                   'YEARLY_CLOTHING_TO_CURRENT_DEBT_RATIO': 'Yearly Clothing : Current Debt',
                                   'YEARLY_EDUCATION_TO_YEARLY_INCOME_RATIO': 'Yearly Education : Yearly Income',
                                   'YEARLY_EDUCATION_TO_CURRENT_SAVINGS_RATIO': 'Yearly Education : Current Savings',
                                   'YEARLY_EDUCATION_TO_CURRENT_DEBT_RATIO': 'Yearly Education : Current Debt',
                                   'YEARLY_ENTERTAINMENT_TO_YEARLY_INCOME_RATIO': 'Yearly Entertainment : Yearly Income',
                                   'YEARLY_ENTERTAINMENT_TO_CURRENT_SAVINGS_RATIO': 'Yearly Entertainment : Current Savings',
                                   'YEARLY_ENTERTAINMENT_TO_CURRENT_DEBT_RATIO': 'Yearly Entertainment : Current Debt',
                                   'YEARLY_LOAN_FINES_TO_YEARLY_INCOME_RATIO': 'Yearly Loan Fines : Yearly Income',
                                   'YEARLY_LOAN_FINES_TO_CURRENT_SAVINGS_RATIO': 'Yearly Loan Fines : Current Savings',
                                   'YEARLY_LOAN_FINES_CURRENT_DEBT_RATIO': 'Yearly Loan Fines : Current Debt',
                                   'YEARLY_GAMBLING_TO_YEARLY_INCOME_RATIO': 'Yearly Gambling : Yearly Income',
                                   'YEARLY_GAMBLING_TO_CURRENT_SAVINGS_RATIO': 'Yearly Gambling : Current Savings',
                                   'YEARLY_GAMBLING_TO_CURRENT_DEBT_RATIO': 'Yearly Gambling : Current Debt',
                                   'YEARLY_GROCERIES_TO_YEARLY_INCOME_RATIO': 'Yearly Groceries : Yearly Income',
                                   'YEARLY_GROCERIES_TO_CURRENT_SAVINGS_RATIO': 'Yearly Groceries : Current Savings',
                                   'YEARLY_GROCERIES_TO-CURRENT_DEBT_RATIO': 'Yearly Groceries : Current Debt',
                                   'YEARLY_HEALTH_TO_YEARLY_INCOME_RATIO': 'Yearly Health : Yearly Income',
                                   'YEARLY_HEALTH__TO_CURRENT_SAVINGS_RATIO': 'Yearly Health : Current Savings',
                                   'YEARLY_HEALTH_TO_CURRENT_DEBT_RATIO': 'Yearly Health : Current Debt',
                                   'YEARLY_HOUSING_TO_YEARLY_INCOME_RATIO': 'Yearly Housing : Yearly Income',
                                   'YEARLY_HOUSING_TO_CURRENT_SAVINGS_RATIO': 'Yearly Housing : Current Savings',
                                   'YEARLY_HOUSING_TO_CURRENT_DEBT_RATIO': 'Yearly Housing : Current Debt',
                                   'YEARLY_TAX_TO_YEARLY_INCOME_RATIO': 'Yearly Tax : Yearly Income',
                                   'YEARLY_TAX_TO_CURRENT_SAVINGS_RATIO': 'Yearly Tax : Current Savings',
                                   'YEARLY_TAX_TO_CURRENT_DEBT_RATIO': 'Yearly Tax : Current Debt',
                                   'YEARLY_TRAVEL_TO_YEARLY_INCOME_RATIO': 'Yearly Travel : Yearly Income',
                                   'YEARLY_TRAVEL_TO_CURRENT_SAVINGS_RATIO': 'Yearly Travel : Current Savings',
                                   'YEARLY_TRAVEL_TO_CURRENT_DEBT_RATIO': 'Yearly Travel : Current Debt',
                                   'YEARLY_UTILITIES_TO_YEARLY_INCOME_RATIO': 'Yearly Utilities : Yearly Income',
                                   'YEARLY_UTILITIES_TO_CURRENT_SAVINGS_RATIO': 'Yearly Utilities : Current Savings',
                                   'YEARLY_UTILITIES_TO_CURRENT_DEBT_RATIO': 'Yearly Utilities : Current Debt',
                                   'YEARLY_EXPENDITURE_TO_YEARLY_INCOME_RATIO': 'Yearly Expenditure : Yearly Income',
                                   'YEARLY_EXPENDITURE_TO_CURRENT_SAVINGS_RATIO': 'Yearly Expenditure : Current Savings',
                                   'YEARLY_EXPENDITURE_TO_CURRENT_DEBT_RATIO': 'Yearly Expenditure : Current Debt',
                                   'CREDIT_SCORE': 'Credit Score'
                                 }) 
                                 
credit_score_df.head()
# Out:
#    Yearly Income  Current Savings : Yearly Income  \
# 0          33269                           0.0000
# 1          77158                           1.1818
# 2          80657                           0.8000
# 3         149971                           7.8182
# 4         181636                           1.8667
#
#    Current Debt : Yearly Income  Current Debt : Current Savings  \
# 0                       16.0000                          1.2000
# 1                        4.0909                          3.4615
# 2                        7.8000                          9.7499
# 3                       16.0000                          2.0465
# 4                        9.3334                          5.0000
#
#    Yearly Clothing : Yearly Income  Yearly Clothing : Current Savings  \
# 0                           0.0568                             0.0000
# 1                           0.0754                             0.0638
# ...

# %%
credit_score_df.columns
# Out:
# Index(['Yearly Income', 'Current Savings : Yearly Income',
#        'Current Debt : Yearly Income', 'Current Debt : Current Savings',
#        'Yearly Clothing : Yearly Income', 'Yearly Clothing : Current Savings',
#        'Yearly Clothing : Current Debt', 'Yearly Education : Yearly Income',
#        'Yearly Education : Current Savings', 'Yearly Education : Current Debt',
#        'Yearly Entertainment : Yearly Income',
#        'Yearly Entertainment : Current Savings',
#        'Yearly Entertainment : Current Debt',
#        'Yearly Loan Fines : Yearly Income',
#        'Yearly Loan Fines : Current Savings',
#        'Yearly Loan Fines : Current Debt', 'Yearly Gambling : Yearly Income',
#        'Yearly Gambling : Current Savings', 'Yearly Gambling : Current Debt',
#        'Yearly Groceries : Yearly Income',
#        'Yearly Groceries : Current Savings', 'Yearly Groceries : Current Debt',
#        'Yearly Health : Yearly Income', 'Yearly Health : Current Savings',
# ...

# %% [markdown]
# # Top 3 positive strongest correlations

# %%
corr_matrix = credit_score_df.corr()

# %%
# Ascending by default

sorted_corr = corr_matrix.unstack().sort_values().drop_duplicates() 
sorted_corr = sorted_corr.iloc[:-1] # removes the last row where column names are the same

# %%
#Strongest correlation is closer to the #1
strongest = sorted_corr.tail(3)
strongest
# Out:
# Yearly Groceries : Current Debt    Yearly Expenditure : Current Debt    0.879746
# Yearly Expenditure : Current Debt  Yearly Utilities : Current Debt      0.917110
# Yearly Utilities : Current Debt    Yearly Groceries : Current Debt      0.953496
# dtype: float64

# %% [markdown]
# # Bottom 3 negative strongest correlations

# %%
#Weakest is the furthest from the #1
weakest = sorted_corr.head(3)
weakest
# Out:
# Credit Score                        Current Debt : Yearly Income       -0.857900
# Yearly Expenditure : Yearly Income  Yearly Income                      -0.564984
# Yearly Travel : Yearly Income       Yearly Utilities : Yearly Income   -0.559546
# dtype: float64

# %% [markdown]
# # Compare and identify strongest 3 pos/neg correlations; isolate

# %% [markdown]
# ## Strong Positive Correlation

# %%
# One data point = one row = one individual 

credit_score_df.plot(x='Yearly Groceries : Current Debt', y='Yearly Expenditure : Current Debt', kind='scatter',
                     title='Positive Correlation 1')
# Out:
# <Axes: title={'center': 'Positive Correlation 1'}, xlabel='Yearly Groceries : Current Debt', ylabel='Yearly Expenditure : Current Debt'>

# %%
X = credit_score_df['Yearly Groceries : Current Debt']
y = credit_score_df['Yearly Expenditure : Current Debt']

# Linear regression
slope, intercept, r_value, p_value, std_err = st.linregress(X, y)

# Plot data points
plt.scatter(X, y, label='Data')

# Plot regression line
plt.plot(X, slope * X + intercept, color='black', label='Linear Regression')

plt.xlabel('Yearly Groceries : Current Debt')
plt.ylabel('Yearly Expenditure : Current Debt')
plt.title('Positive Correlation 1')
plt.legend()
plt.show()

# %%
credit_score_df.plot(x='Yearly Expenditure : Current Debt', y='Yearly Utilities : Current Debt', kind='scatter',
                    title='Positive Correlation 2')
# Out:
# <Axes: title={'center': 'Positive Correlation 2'}, xlabel='Yearly Expenditure : Current Debt', ylabel='Yearly Utilities : Current Debt'>

# %%
X = credit_score_df['Yearly Expenditure : Current Debt']
y = credit_score_df['Yearly Utilities : Current Debt']

# Linear regression
slope, intercept, r_value, p_value, std_err = st.linregress(X, y)

# Plot data points
plt.scatter(X, y, label='Data')

# Plot regression line
plt.plot(X, slope * X + intercept, color='black', label='Linear Regression')

plt.xlabel('Yearly Expenditure : Current Debt')
plt.ylabel('Yearly Utilities : Current Debt')
plt.title('Positive Correlation 2')
plt.legend()
plt.show()

# %%
credit_score_df.plot(x='Yearly Utilities : Current Debt', y='Yearly Groceries : Current Debt', kind='scatter',
                    title='Positive Correlation 3')
# Out:
# <Axes: title={'center': 'Positive Correlation 3'}, xlabel='Yearly Utilities : Current Debt', ylabel='Yearly Groceries : Current Debt'>

# %%
X = credit_score_df['Yearly Utilities : Current Debt']
y = credit_score_df['Yearly Groceries : Current Debt']

# Linear regression
slope, intercept, r_value, p_value, std_err = st.linregress(X, y)

# Plot data points
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Data')


# Plot regression line
plt.plot(X, slope * X + intercept, color='black', label='Linear Regression')

plt.xlabel('Yearly Utilities : Current Debt')
plt.ylabel('Yearly Groceries : Current Debt')
plt.title('Positive Correlation 3')
plt.legend()
plt.show()

# %% [markdown]
# ## Strong Negative Correlation

# %%
credit_score_df.plot(x='Credit Score', y='Current Debt : Yearly Income', kind='scatter',
                    color='red', title='Negative Correlation 1')
# Out:
# <Axes: title={'center': 'Negative Correlation 1'}, xlabel='Credit Score', ylabel='Current Debt : Yearly Income'>

# %%
X = credit_score_df['Credit Score']
y = credit_score_df['Current Debt : Yearly Income']

# Linear regression
slope, intercept, r_value, p_value, std_err = st.linregress(X, y)

# Plot data points
plt.figure(figsize=(10, 6))  # Resize in order to map all data points 
plt.scatter(X, y, color='red', label='Data')

# Plot the regression line
plt.plot(X, slope * X + intercept, color='black', label='Linear Regression')

plt.xlabel('Credit Score')
plt.ylabel('Current Debt : Yearly Income')
plt.title('Negative Correlation 1')
plt.legend()
plt.ylim(-1, 40)  # adjusted y axis to capture all data points
plt.show()

# %%
credit_score_df.plot(x='Yearly Expenditure : Yearly Income', y='Yearly Income', kind='scatter',
                    color='red', title='Negative Correlation 2')
# Out:
# <Axes: title={'center': 'Negative Correlation 2'}, xlabel='Yearly Expenditure : Yearly Income', ylabel='Yearly Income'>

# %%
X = credit_score_df['Yearly Expenditure : Yearly Income']
y = credit_score_df['Yearly Income']

# Linear regression
slope, intercept, r_value, p_value, std_err = st.linregress(X, y)

# Plot data points
plt.scatter(X, y, color='red', label='Data')

# Plot regression line
plt.plot(X, slope * X + intercept, color='black', label='Linear Regression')

plt.xlabel('Yearly Expenditure : Yearly Income')
plt.ylabel('Yearly Income')
plt.title('Negative Correlation 2')
plt.legend()
plt.ylim(-100000, 700000) # adjusted y axis to capture all data points
plt.show()

# %%
credit_score_df.plot(x='Yearly Travel : Yearly Income', y='Yearly Utilities : Yearly Income', kind='scatter',
                    color='red', title='Negative Correlation 3')
# Out:
# <Axes: title={'center': 'Negative Correlation 3'}, xlabel='Yearly Travel : Yearly Income', ylabel='Yearly Utilities : Yearly Income'>

# %%
X = credit_score_df['Yearly Travel : Yearly Income']
y = credit_score_df['Yearly Utilities : Yearly Income']

# Linear regression
slope, intercept, r_value, p_value, std_err = st.linregress(X, y)

# Plot data points
plt.scatter(X, y, color='red', label='Data')

# Plot regression line
plt.plot(X, slope * X + intercept, color='black', label='Linear Regression')

plt.xlabel('Yearly Travel : Yearly Income')
plt.ylabel('Yearly Utilities : Yearly Income')
plt.title('Negative Correlation 3')
plt.legend()
plt.ylim(-0.02, 0.16) # adjusted y axis to capture all data points
plt.show()

# %% [markdown]
# # Correlation to Credit Score Only

# %%
#correlation with just credit score of entire df
credit_corr = corr_matrix['Credit Score']

# %%
# highest corr is at the bottom (closer to the #1)
# [:-1] removes last row (Credit Score)
credit_corr.sort_values().iloc[:-1]
# Out:
# Current Debt : Yearly Income             -0.857900
# Current Debt : Current Savings           -0.454068
# Yearly Education : Yearly Income         -0.303268
# Yearly Utilities : Current Savings       -0.210996
# Yearly Education : Current Savings       -0.195299
# Yearly Health : Current Savings          -0.186657
# Yearly Groceries : Current Savings       -0.183504
# Yearly Groceries : Yearly Income         -0.182672
# Yearly Gambling : Yearly Income          -0.158533
# Yearly Housing : Current Savings         -0.131936
# Yearly Clothing : Current Savings        -0.086240
# Yearly Gambling : Current Savings        -0.080030
# Yearly Expenditure : Current Savings     -0.074449
# Yearly Loan Fines : Current Savings      -0.057987
# Yearly Loan Fines : Yearly Income        -0.053924
# Yearly Clothing : Yearly Income          -0.044721
# Yearly Expenditure : Yearly Income       -0.030981
# Yearly Travel : Current Savings          -0.029922
# ...

# %% [markdown]
# ## Positive

# %%
credit_score_df.plot(x='Credit Score', y='Yearly Groceries : Current Debt', kind='scatter',
                    title='Positive Correlation to Credit Score 1')
#credit_score.plot(x='YEARLY_GROCERIES_TO-CURRENT_DEBT_RATIO', y= 'CREDIT_SCORE', kind='scatter')
# Out:
# <Axes: title={'center': 'Positive Correlation to Credit Score 1'}, xlabel='Credit Score', ylabel='Yearly Groceries : Current Debt'>

# %%
X = credit_score_df['Credit Score']
y = credit_score_df['Yearly Groceries : Current Debt']

# Linear regression
slope, intercept, r_value, p_value, std_err = st.linregress(X, y)

# Plot data points
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Data')


# Plot regression line
plt.plot(X, slope * X + intercept, color='black', label='Linear Regression')

plt.xlabel('Credit Score')
plt.ylabel('Yearly Groceries : Current Debt')
plt.title('Positive Correlation to Credit Score 1')
plt.legend()
plt.show()

# %%
credit_score_df.plot(x='Credit Score', y='Yearly Utilities : Current Debt', kind='scatter',
                    title='Positive Correlation to Credit Score 2')
# Out:
# <Axes: title={'center': 'Positive Correlation to Credit Score 2'}, xlabel='Credit Score', ylabel='Yearly Utilities : Current Debt'>

# %%
X = credit_score_df['Credit Score']
y = credit_score_df['Yearly Utilities : Current Debt']

# Linear regression
slope, intercept, r_value, p_value, std_err = st.linregress(X, y)

# Plot data points
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Data')


# Plot regression line
plt.plot(X, slope * X + intercept, color='black', label='Linear Regression')

plt.xlabel('Credit Score')
plt.ylabel('Yearly Utilities : Current Debt')
plt.title('Positive Correlation to Credit Score 2')
plt.legend()
plt.show()

# %%
credit_score_df.plot(x='Credit Score', y='Yearly Expenditure : Current Debt', kind='scatter',
                    title='Positive Correlation to Credit Score 3')
# Out:
# <Axes: title={'center': 'Positive Correlation to Credit Score 3'}, xlabel='Credit Score', ylabel='Yearly Expenditure : Current Debt'>

# %%
X = credit_score_df['Credit Score']
y = credit_score_df['Yearly Expenditure : Current Debt']

# Linear regression
slope, intercept, r_value, p_value, std_err = st.linregress(X, y)

# Plot data points
plt.figure(figsize=(10, 6))
plt.scatter(X, y, label='Data')


# Plot regression line
plt.plot(X, slope * X + intercept, color='black', label='Linear Regression')

plt.xlabel('Credit Score')
plt.ylabel('Yearly Expenditure : Current Debt')
plt.title('Positive Correlation to Credit Score 3')
plt.legend()
plt.show()

# %% [markdown]
# ## Negative

# %%
# STRONG NEGATIVE CORR 
credit_score_df.plot(x='Credit Score', y='Current Debt : Yearly Income', kind='scatter',
                    color='red', title='Negative Correlation to Credit Score 1')
# Out:
# <Axes: title={'center': 'Negative Correlation to Credit Score 1'}, xlabel='Credit Score', ylabel='Current Debt : Yearly Income'>

# %%
X = credit_score_df['Credit Score']
y = credit_score_df['Current Debt : Yearly Income']

# Linear regression
slope, intercept, r_value, p_value, std_err = st.linregress(X, y)

# Plot data points
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='red', label='Data')

# Plot regression line
plt.plot(X, slope * X + intercept, color='black', label='Linear Regression')

plt.xlabel('Credit Score')
plt.ylabel('Current Debt : Yearly Income')
plt.title('Negative Correlation to Credit Score 1')
plt.legend()
plt.ylim(-5, 40) # adjusted y axis to capture all data points
plt.show()

# %%
credit_score_df.plot(x='Credit Score', y='Current Debt : Current Savings', kind='scatter',
                    color='red', title='Negative Correlation to Credit Score 2')
# Out:
# <Axes: title={'center': 'Negative Correlation to Credit Score 2'}, xlabel='Credit Score', ylabel='Current Debt : Current Savings'>

# %%
X = credit_score_df['Credit Score']
y = credit_score_df['Current Debt : Current Savings']

# Linear regression
slope, intercept, r_value, p_value, std_err = st.linregress(X, y)

# Plot data points
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='red', label='Data')

# Plot regression line
plt.plot(X, slope * X + intercept, color='black', label='Linear Regression')

plt.xlabel('Credit Score')
plt.ylabel('Current Debt : Current Savings')
plt.title('Negative Correlation to Credit Score 2')
plt.legend()
#plt.ylim(-5, 40) # adjusted y axis to capture all data points
plt.show()

# %%
credit_score_df.plot(x='Credit Score', y='Yearly Education : Yearly Income', kind='scatter',
                    color='red', title='Negative Correlation to Credit Score 3')
# Out:
# <Axes: title={'center': 'Negative Correlation to Credit Score 3'}, xlabel='Credit Score', ylabel='Yearly Education : Yearly Income'>

# %%
X = credit_score_df['Credit Score']
y = credit_score_df['Yearly Education : Yearly Income']

# Linear regression
slope, intercept, r_value, p_value, std_err = st.linregress(X, y)

# Plot data points
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='red', label='Data')

# Plot regression line
plt.plot(X, slope * X + intercept, color='black', label='Linear Regression')

plt.xlabel('Credit Score')
plt.ylabel('Yearly Education : Yearly Income')
plt.title('Negative Correlation to Credit Score 3')
plt.legend()
plt.show()

# %% [markdown]
# # Identify outliers in credit_score.csv by excel column (T - AN) compared to AO(Credit_Score)

# %%
#FUNCTION TO GET OUTLIERS FROM DF
def get_outliers (df):
    Q1 = df.quantile(0.25)
    Q3 = df.quantile(0.75)
    difference = Q3-Q1
    lower = Q1-1.5* difference
    upper = Q3+1.5* difference
    outliers = (df<lower)|(df>upper)
    return outliers

# %%
#get names from problematic data from T-AN
columns_t_an = ['Yearly Groceries : Yearly Income',
                'Yearly Groceries : Current Savings',
                'Yearly Groceries : Current Debt',
                'Yearly Health : Yearly Income', 
                'Yearly Health : Current Savings',
                'Yearly Health : Current Debt', 
                'Yearly Housing : Yearly Income',
                'Yearly Housing : Current Savings', 
                'Yearly Housing : Current Debt',
                'Yearly Tax : Yearly Income', 
                'Yearly Tax : Current Savings',
                'Yearly Tax : Current Debt', 
                'Yearly Travel : Yearly Income',
                'Yearly Travel : Current Savings', 
                'Yearly Travel : Current Debt',
                'Yearly Utilities : Yearly Income',
                'Yearly Utilities : Current Savings', 
                'Yearly Utilities : Current Debt',
                'Yearly Expenditure : Yearly Income',
                'Yearly Expenditure : Current Savings',
                'Yearly Expenditure : Current Debt'
]

compared_df = credit_score_df[columns_t_an].sub(credit_score_df['Credit Score'], axis=0)
outliers = compared_df.apply(get_outliers)

# %%
# columns with outliers relative to credit score and the # of outliers in each column
count_outliers = outliers.sum()
count_outliers
# Out:
# Yearly Groceries : Yearly Income        34
# Yearly Groceries : Current Savings      34
# Yearly Groceries : Current Debt         34
# Yearly Health : Yearly Income           34
# Yearly Health : Current Savings         34
# Yearly Health : Current Debt            34
# Yearly Housing : Yearly Income          34
# Yearly Housing : Current Savings        34
# Yearly Housing : Current Debt           34
# Yearly Tax : Yearly Income              34
# Yearly Tax : Current Savings            34
# Yearly Tax : Current Debt               34
# Yearly Travel : Yearly Income           34
# Yearly Travel : Current Savings         34
# Yearly Travel : Current Debt            34
# Yearly Utilities : Yearly Income        34
# Yearly Utilities : Current Savings      34
# Yearly Utilities : Current Debt         34
# Yearly Expenditure : Yearly Income      34
# Yearly Expenditure : Current Savings    34
# Yearly Expenditure : Current Debt       34
# dtype: int64

# %%
#outliers says true
outliers[outliers['Yearly Groceries : Yearly Income']==True]
# Out:
#      Yearly Groceries : Yearly Income  Yearly Groceries : Current Savings  \
# 46                               True                                True
# 113                              True                                True
# 124                              True                                True
# 130                              True                                True
# 161                              True                                True
# 168                              True                                True
# 225                              True                                True
# 238                              True                                True
# 246                              True                                True
# 289                              True                                True
# 323                              True                                True
# 343                              True                                True
# ...

# %%
#outliers with numerical value
credit_score_df[outliers['Yearly Groceries : Yearly Income']==True]
# Out:
#      Yearly Income  Current Savings : Yearly Income  \
# 46            8147                           0.0910
# 113          12615                           0.6250
# 124          13271                           0.2000
# 130          16232                           0.2000
# 161           2657                           0.7000
# 168          20118                           0.6250
# 225          42102                           0.0000
# 238          25623                           0.7778
# 246          11722                           0.4445
# 289          28638                           0.3333
# 323          22112                           0.8000
# 343           6140                           0.8889
# 373          14680                           1.2500
# 401          39344                           0.8889
# 472              0                           0.0000
# 499          25397                           0.5000
# 510          26607                           0.6364
# ...

# %% [markdown]
# # Identifed Outliers Graphed (column (T - AN) compared to AO(Credit_Score))

# %%
#data to graph outliers of all compared columns... pull from count_outliers
outliers_df= credit_score_df[outliers['Yearly Groceries : Yearly Income']==True]

# %%
outliers_df.plot(x='Credit Score', y='Yearly Groceries : Yearly Income', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Groceries : Yearly Income'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Groceries : Current Savings', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Groceries : Current Savings'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Groceries : Current Debt', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Groceries : Current Debt'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Health : Yearly Income', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Health : Yearly Income'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Health : Current Savings', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Health : Current Savings'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Health : Current Debt', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Health : Current Debt'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Housing : Yearly Income', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Housing : Yearly Income'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Housing : Current Savings', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Housing : Current Savings'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Housing : Current Debt', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Housing : Current Debt'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Tax : Yearly Income', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Tax : Yearly Income'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Tax : Current Savings', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Tax : Current Savings'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Tax : Current Debt', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Tax : Current Debt'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Travel : Yearly Income', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Travel : Yearly Income'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Travel : Current Savings', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Travel : Current Savings'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Travel : Current Debt', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Travel : Current Debt'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Utilities : Yearly Income', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Utilities : Yearly Income'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Utilities : Current Savings', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Utilities : Current Savings'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Utilities : Current Debt', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Utilities : Current Debt'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Expenditure : Yearly Income', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Expenditure : Yearly Income'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Expenditure : Current Savings', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Expenditure : Current Savings'>

# %%
outliers_df.plot(x='Credit Score', y='Yearly Expenditure : Current Debt', kind='scatter',
                color='black')
# Out:
# <Axes: xlabel='Credit Score', ylabel='Yearly Expenditure : Current Debt'>
